# %% [markdown]
# <a href="https://colab.research.google.com/github/beeravallipavani/OIBSIP/blob/main/copy_of_regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
#Each review (row) is of different size. This data needs to be made uniform.
# i.e. each reviuew (i.e. row) needs to be onehotencoded to a length of 10,000 (we have decided to have only 10000 features)
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
#create the layers
from keras import models
from keras import layers
from keras import regularizers

model = models.Sequential()
#model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))

#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu'))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))

model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 94ms/step - loss: 7.2292 - categorical_accuracy: 0.4676 - val_loss: 3.7622 - val_categorical_accuracy: 0.5475
# Epoch 2/25
# 16/16 [==============================] - 1s 60ms/step - loss: 3.4247 - categorical_accuracy: 0.5449 - val_loss: 3.1168 - val_categorical_accuracy: 0.5750
# Epoch 3/25
# 16/16 [==============================] - 1s 63ms/step - loss: 3.0605 - categorical_accuracy: 0.5741 - val_loss: 2.8807 - val_categorical_accuracy: 0.6087
# Epoch 4/25
# 16/16 [==============================] - 1s 59ms/step - loss: 2.8564 - categorical_accuracy: 0.6164 - val_loss: 2.7123 - val_categorical_accuracy: 0.6350
# Epoch 5/25
# 16/16 [==============================] - 1s 85ms/step - loss: 2.7146 - categorical_accuracy: 0.6355 - val_loss: 2.6454 - val_categorical_accuracy: 0.6550
# Epoch 6/25
# 16/16 [==============================] - 2s 98ms/step - loss: 2.5971 - categorical_accuracy: 0.6597 - val_loss: 2.4978 - val_categorical_accuracy: 0.6787
# Epoch 7/25
# 16/16 [==============================] - 1s 72ms/step - loss: 2.4933 - categorical_accuracy: 0.6698 - val_loss: 2.4205 - val_categorical_accuracy: 0.6888
# Epoch 8/25
# 16/16 [==============================] - 1s 59ms/step - loss: 2.4164 - categorical_accuracy: 0.6797 - val_loss: 2.3565 - val_categorical_accuracy: 0.6950
# Epoch 9/25
# 16/16 [==============================] - 1s 59ms/step - loss: 2.3454 - categorical_accuracy: 0.6835 - val_loss: 2.3114 - val_categorical_accuracy: 0.6737
# Epoch 10/25
# 16/16 [==============================] - 1s 58ms/step - loss: 2.2847 - categorical_accuracy: 0.6868 - val_loss: 2.2196 - val_categorical_accuracy: 0.6975
# Epoch 11/25
# 16/16 [==============================] - 1s 60ms/step - loss: 2.2331 - categorical_accuracy: 0.6885 - val_loss: 2.1795 - val_categorical_accuracy: 0.6988
# Epoch 12/25
# 16/16 [==============================] - 1s 62ms/step - loss: 2.1835 - categorical_accuracy: 0.6959 - val_loss: 2.1352 - val_categorical_accuracy: 0.6988
# Epoch 13/25
# 16/16 [==============================] - 1s 60ms/step - loss: 2.1534 - categorical_accuracy: 0.6938 - val_loss: 2.1138 - val_categorical_accuracy: 0.6950
# Epoch 14/25
# 16/16 [==============================] - 1s 58ms/step - loss: 2.1225 - categorical_accuracy: 0.6946 - val_loss: 2.0774 - val_categorical_accuracy: 0.6975
# Epoch 15/25
# 16/16 [==============================] - 1s 60ms/step - loss: 2.0939 - categorical_accuracy: 0.6982 - val_loss: 2.0663 - val_categorical_accuracy: 0.6950
# Epoch 16/25
# 16/16 [==============================] - 1s 59ms/step - loss: 2.0703 - categorical_accuracy: 0.6982 - val_loss: 2.0654 - val_categorical_accuracy: 0.6900
# Epoch 17/25
# 16/16 [==============================] - 1s 65ms/step - loss: 2.0555 - categorical_accuracy: 0.6965 - val_loss: 2.0212 - val_categorical_accuracy: 0.6988
# Epoch 18/25
# 16/16 [==============================] - 2s 100ms/step - loss: 2.0360 - categorical_accuracy: 0.7003 - val_loss: 2.0035 - val_categorical_accuracy: 0.7013
# Epoch 19/25
# 16/16 [==============================] - 1s 88ms/step - loss: 2.0119 - categorical_accuracy: 0.7012 - val_loss: 1.9984 - val_categorical_accuracy: 0.7013
# Epoch 20/25
# 16/16 [==============================] - 1s 58ms/step - loss: 1.9976 - categorical_accuracy: 0.7007 - val_loss: 1.9762 - val_categorical_accuracy: 0.7013
# Epoch 21/25
# 16/16 [==============================] - 1s 58ms/step - loss: 1.9859 - categorical_accuracy: 0.7024 - val_loss: 1.9690 - val_categorical_accuracy: 0.7013
# Epoch 22/25
# 16/16 [==============================] - 1s 57ms/step - loss: 1.9709 - categorical_accuracy: 0.7034 - val_loss: 1.9509 - val_categorical_accuracy: 0.7013
# Epoch 23/25
# 16/16 [==============================] - 1s 56ms/step - loss: 1.9559 - categorical_accuracy: 0.7063 - val_loss: 1.9529 - val_categorical_accuracy: 0.7050
# Epoch 24/25
# 16/16 [==============================] - 1s 57ms/step - loss: 1.9463 - categorical_accuracy: 0.7069 - val_loss: 1.9296 - val_categorical_accuracy: 0.7100
# Epoch 25/25
# 16/16 [==============================] - 1s 56ms/step - loss: 1.9314 - categorical_accuracy: 0.7099 - val_loss: 1.9206 - val_categorical_accuracy: 0.7050

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
