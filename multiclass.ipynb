# %% [markdown]
# <a href="https://colab.research.google.com/github/beeravallipavani/OIBSIP/blob/main/multiclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
#Each review (row) is of different size. This data needs to be made uniform.
# i.e. each reviuew (i.e. row) needs to be onehotencoded to a length of 10,000 (we have decided to have only 10000 features)
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
#create the layers
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 61ms/step - loss: 2.8969 - categorical_accuracy: 0.4958 - val_loss: 1.9613 - val_categorical_accuracy: 0.6187
# Epoch 2/25
# 16/16 [==============================] - 1s 46ms/step - loss: 1.6187 - categorical_accuracy: 0.6761 - val_loss: 1.4103 - val_categorical_accuracy: 0.6900
# Epoch 3/25
# 16/16 [==============================] - 1s 62ms/step - loss: 1.2193 - categorical_accuracy: 0.7400 - val_loss: 1.2140 - val_categorical_accuracy: 0.7387
# Epoch 4/25
# 16/16 [==============================] - 1s 78ms/step - loss: 0.9983 - categorical_accuracy: 0.7876 - val_loss: 1.1066 - val_categorical_accuracy: 0.7625
# Epoch 5/25
# 16/16 [==============================] - 1s 74ms/step - loss: 0.8332 - categorical_accuracy: 0.8184 - val_loss: 1.0364 - val_categorical_accuracy: 0.7875
# Epoch 6/25
# 16/16 [==============================] - 1s 45ms/step - loss: 0.7002 - categorical_accuracy: 0.8524 - val_loss: 0.9728 - val_categorical_accuracy: 0.8025
# Epoch 7/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.5863 - categorical_accuracy: 0.8770 - val_loss: 0.9393 - val_categorical_accuracy: 0.8037
# Epoch 8/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.4969 - categorical_accuracy: 0.8950 - val_loss: 0.9081 - val_categorical_accuracy: 0.8075
# Epoch 9/25
# 16/16 [==============================] - 1s 43ms/step - loss: 0.4236 - categorical_accuracy: 0.9087 - val_loss: 0.8985 - val_categorical_accuracy: 0.8125
# Epoch 10/25
# 16/16 [==============================] - 1s 44ms/step - loss: 0.3646 - categorical_accuracy: 0.9182 - val_loss: 0.8910 - val_categorical_accuracy: 0.8163
# Epoch 11/25
# 16/16 [==============================] - 1s 46ms/step - loss: 0.3135 - categorical_accuracy: 0.9313 - val_loss: 0.9166 - val_categorical_accuracy: 0.8012
# Epoch 12/25
# 16/16 [==============================] - 1s 45ms/step - loss: 0.2777 - categorical_accuracy: 0.9369 - val_loss: 0.9178 - val_categorical_accuracy: 0.8025
# Epoch 13/25
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2463 - categorical_accuracy: 0.9421 - val_loss: 0.9081 - val_categorical_accuracy: 0.8138
# Epoch 14/25
# 16/16 [==============================] - 1s 45ms/step - loss: 0.2214 - categorical_accuracy: 0.9452 - val_loss: 0.9073 - val_categorical_accuracy: 0.8112
# Epoch 15/25
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1961 - categorical_accuracy: 0.9499 - val_loss: 0.9407 - val_categorical_accuracy: 0.8100
# Epoch 16/25
# 16/16 [==============================] - 1s 43ms/step - loss: 0.1807 - categorical_accuracy: 0.9537 - val_loss: 0.9256 - val_categorical_accuracy: 0.8150
# Epoch 17/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1765 - categorical_accuracy: 0.9537 - val_loss: 0.9355 - val_categorical_accuracy: 0.8125
# Epoch 18/25
# 16/16 [==============================] - 1s 44ms/step - loss: 0.1537 - categorical_accuracy: 0.9551 - val_loss: 0.9693 - val_categorical_accuracy: 0.8025
# Epoch 19/25
# 16/16 [==============================] - 1s 54ms/step - loss: 0.1469 - categorical_accuracy: 0.9556 - val_loss: 0.9692 - val_categorical_accuracy: 0.8050
# Epoch 20/25
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1396 - categorical_accuracy: 0.9581 - val_loss: 0.9734 - val_categorical_accuracy: 0.8112
# Epoch 21/25
# 16/16 [==============================] - 1s 85ms/step - loss: 0.1333 - categorical_accuracy: 0.9567 - val_loss: 0.9798 - val_categorical_accuracy: 0.8100
# Epoch 22/25
# 16/16 [==============================] - 1s 79ms/step - loss: 0.1272 - categorical_accuracy: 0.9566 - val_loss: 0.9813 - val_categorical_accuracy: 0.8100
# Epoch 23/25
# 16/16 [==============================] - 1s 76ms/step - loss: 0.1280 - categorical_accuracy: 0.9561 - val_loss: 0.9934 - val_categorical_accuracy: 0.8125
# Epoch 24/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1247 - categorical_accuracy: 0.9565 - val_loss: 1.0121 - val_categorical_accuracy: 0.8138
# Epoch 25/25
# 16/16 [==============================] - 1s 43ms/step - loss: 0.1149 - categorical_accuracy: 0.9589 - val_loss: 1.0281 - val_categorical_accuracy: 0.8112

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
